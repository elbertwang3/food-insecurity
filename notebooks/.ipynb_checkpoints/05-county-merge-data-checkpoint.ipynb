# %%
import pandas as pd
from census import Census
from us import states
from shapely.geometry import Point
import geopandas as gp
from scipy.stats import ttest_ind
import rtree
pd.set_option('display.max_columns', 500)

# %%
df = pd.read_csv('../data/self_sufficiency_and_costs.csv')
df.head()
# Out:
#   Family Type  Adult(s)  Infant(s)  Preshooler(s)  Schoolager(s)  Teenager(s)  \
# 0  a1i0p1s1t0         1          0            1.0            1.0          0.0
# 1  a1i0p1s1t0         1          0            1.0            1.0          0.0
# 2  a1i0p1s1t0         1          0            1.0            1.0          0.0
# 3  a1i0p1s1t0         1          0            1.0            1.0          0.0
# 4  a1i0p1s1t0         1          0            1.0            1.0          0.0
#
#   State  Year  All Families Table #            County Housing Costs  \
# 0    CA  2018                     1    Alameda County       $2,322
# 1    CA  2018                     2     Alpine County         $940
# 2    CA  2018                     3     Amador County       $1,055
# 3    CA  2018                     4      Butte County         $992
# 4    CA  2018                     5  Calaveras County         $902
#
#   Child Care Costs Food Costs Transportation Costs Health Care Costs  \
# ...

# %%
all_counties = (
    gp.read_file(
        "../data/cb_2017_us_county_500k/cb_2017_us_county_500k.shp"
    )
)
all_counties.head()
# Out:
#   STATEFP COUNTYFP  COUNTYNS        AFFGEOID  GEOID     NAME LSAD       ALAND  \
# 0      01      005  00161528  0500000US01005  01005  Barbour   06  2292144656
# 1      01      023  00161537  0500000US01023  01023  Choctaw   06  2365869837
# 2      01      035  00161543  0500000US01035  01035  Conecuh   06  2201948618
# 3      01      051  00161551  0500000US01051  01051   Elmore   06  1601762124
# 4      01      065  00161558  0500000US01065  01065     Hale   06  1667907107
#
#      AWATER                                           geometry
# 0  50538698  POLYGON ((-85.74803199999999 31.619181, -85.74...
# 1  19144469  POLYGON ((-88.47322699999999 31.893856, -88.46...
# 2   6643480  POLYGON ((-87.42720399999999 31.26436, -87.425...
# 3  99965171  POLYGON ((-86.41333499999999 32.750591, -86.37...
# 4  32423356  POLYGON ((-87.870464 32.762442, -87.868184 32....

# %%
ca_counties = all_counties.loc[all_counties['STATEFP'] == '06']
ca_counties.head()
# Out:
#    STATEFP COUNTYFP  COUNTYNS        AFFGEOID  GEOID          NAME LSAD  \
# 18      06      001  01675839  0500000US06001  06001       Alameda   06
# 19      06      005  01675841  0500000US06005  06005        Amador   06
# 20      06      013  01675903  0500000US06013  06013  Contra Costa   06
# 21      06      023  01681908  0500000US06023  06023      Humboldt   06
# 22      06      037  00277283  0500000US06037  06037   Los Angeles   06
#
#           ALAND      AWATER                                           geometry
# 18   1909616630   216916717  POLYGON ((-122.342253 37.805558, -122.33411840...
# 19   1539933576    29470568  POLYGON ((-121.027406 38.50354, -121.027472 38...
# 20   1857310903   225193562  POLYGON ((-122.42976 37.965405, -122.418592 37...
# 21   9241251740  1254039383  POLYGON ((-124.408601 40.44320099999999, -124....
# 22  10510588451  1794793532  (POLYGON ((-118.604415 33.478552, -118.598783 ...

# %%
df['NAME'] = df['County'].str.replace(' County', '')
df.head()
# Out:
#   Family Type  Adult(s)  Infant(s)  Preshooler(s)  Schoolager(s)  Teenager(s)  \
# 0  a1i0p1s1t0         1          0            1.0            1.0          0.0
# 1  a1i0p1s1t0         1          0            1.0            1.0          0.0
# 2  a1i0p1s1t0         1          0            1.0            1.0          0.0
# 3  a1i0p1s1t0         1          0            1.0            1.0          0.0
# 4  a1i0p1s1t0         1          0            1.0            1.0          0.0
#
#   State  Year  All Families Table #            County Housing Costs  \
# 0    CA  2018                     1    Alameda County       $2,322
# 1    CA  2018                     2     Alpine County         $940
# 2    CA  2018                     3     Amador County       $1,055
# 3    CA  2018                     4      Butte County         $992
# 4    CA  2018                     5  Calaveras County         $902
#
#   Child Care Costs Food Costs Transportation Costs Health Care Costs  \
# ...

# %%
ca_counties_merged = ca_counties.merge(df, on='NAME')

# %%
ca_counties_merged.head()
# Out:
#   STATEFP COUNTYFP  COUNTYNS        AFFGEOID  GEOID          NAME LSAD  \
# 0      06      001  01675839  0500000US06001  06001       Alameda   06
# 1      06      005  01675841  0500000US06005  06005        Amador   06
# 2      06      013  01675903  0500000US06013  06013  Contra Costa   06
# 3      06      023  01681908  0500000US06023  06023      Humboldt   06
# 4      06      037  00277283  0500000US06037  06037   Los Angeles   06
#
#          ALAND      AWATER                                           geometry  \
# 0   1909616630   216916717  POLYGON ((-122.342253 37.805558, -122.33411840...
# 1   1539933576    29470568  POLYGON ((-121.027406 38.50354, -121.027472 38...
# 2   1857310903   225193562  POLYGON ((-122.42976 37.965405, -122.418592 37...
# 3   9241251740  1254039383  POLYGON ((-124.408601 40.44320099999999, -124....
# 4  10510588451  1794793532  (POLYGON ((-118.604415 33.478552, -118.598783 ...
#
# ...

# %%
ca_counties_merged.shape
# Out:
# (58, 34)

# %%
dropped = ca_counties_merged.drop(columns=["COUNTYNS", "AFFGEOID", "LSAD", "ALAND", 'AWATER', 'Adult(s)', "Infant(s)", "Preshooler(s)", "Schoolager(s)","Teenager(s)", "All Families Table #", "Child Care Tax Credit (-)", "Child Tax Credit (-)", "Child Care Tax Credit (-)"])

# %%
dropped.head()
# Out:
#   STATEFP COUNTYFP  GEOID          NAME  \
# 0      06      001  06001       Alameda
# 1      06      005  06005        Amador
# 2      06      013  06013  Contra Costa
# 3      06      023  06023      Humboldt
# 4      06      037  06037   Los Angeles
#
#                                             geometry Family Type State  Year  \
# 0  POLYGON ((-122.342253 37.805558, -122.33411840...  a1i0p1s1t0    CA  2018
# 1  POLYGON ((-121.027406 38.50354, -121.027472 38...  a1i0p1s1t0    CA  2018
# 2  POLYGON ((-122.42976 37.965405, -122.418592 37...  a1i0p1s1t0    CA  2018
# 3  POLYGON ((-124.408601 40.44320099999999, -124....  a1i0p1s1t0    CA  2018
# 4  (POLYGON ((-118.604415 33.478552, -118.598783 ...  a1i0p1s1t0    CA  2018
#
#                 County Housing Costs Child Care Costs Food Costs  \
# 0       Alameda County       $2,322           $2,312       $698
# 1        Amador County       $1,055           $1,429       $771
# ...
